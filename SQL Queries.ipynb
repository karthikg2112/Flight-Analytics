# %%
import sqlite3

conn_sqlite = sqlite3.connect('flight_data.db')
cursor = conn_sqlite.cursor()
print("Connected to SQLite database 'flight_data.db' successfully.")
# Out:
# Connected to SQLite database 'flight_data.db' successfully.

# %% [markdown]
# Query Execution

# %% [markdown]
# 1. Total number of flights for each aircraft model, listing the model and its count.

# %%
import sqlite3
import pandas as pd
from tabulate import tabulate

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    ad_arrival.full_name AS destination_airport,
    CAST(SUM(CASE WHEN na.flight_status = 'Delayed' THEN 1 ELSE 0 END) AS REAL) * 100 / COUNT(na.flight_status) AS percentage_delayed,
    COUNT(na.flight_status) AS total_arrivals
FROM
    new_arrivals_data na
JOIN
    airports_data ad_arrival ON na.arrival_airport_iata = ad_arrival.iata_code
WHERE
    ad_arrival.full_name IS NOT NULL AND ad_arrival.full_name != ''
GROUP BY
    destination_airport
HAVING
    total_arrivals > 0
ORDER BY
    percentage_delayed DESC;
"""

df_delayed_arrivals_percentage = pd.read_sql_query(query, conn)

conn.close()

print(tabulate(df_delayed_arrivals_percentage, headers='keys', tablefmt='grid'))
# Out:
# +----+------------------------------+----------------------+------------------+
# |    | destination_airport          |   percentage_delayed |   total_arrivals |
# +====+==============================+======================+==================+
# |  0 | Bangalore Bengaluru          |             5.58659  |              179 |
# +----+------------------------------+----------------------+------------------+
# |  1 | Paris Charles de Gaulle      |             0.646552 |              464 |
# +----+------------------------------+----------------------+------------------+
# |  2 | Shanghai Pudong              |             0        |              906 |
# +----+------------------------------+----------------------+------------------+
# |  3 | New Delhi Indira Gandhi      |             0        |              269 |
# +----+------------------------------+----------------------+------------------+
# |  4 | Mumbai Chhatrapati Shivaji   |             0        |              214 |
# +----+------------------------------+----------------------+------------------+
# |  5 | Indore Devi Ahilyabai Holkar |             0        |               19 |
# +----+------------------------------+----------------------+------------------+
# |  6 | Hyderabad Rajiv Gandhi       |             0        |              121 |
# +----+------------------------------+----------------------+------------------+
# |  7 | Frankfurt-am-Main            |             0        |              435 |
# +----+------------------------------+----------------------+------------------+
# |  8 | Dubai                        |             0        |              363 |
# +----+------------------------------+----------------------+------------------+
# |  9 | Dallas-Fort Worth            |             0        |              430 |
# +----+------------------------------+----------------------+------------------+
# | 10 | Chennai                      |             0        |               99 |
# +----+------------------------------+----------------------+------------------+
# | 11 | Amsterdam Schiphol           |             0        |              182 |
# +----+------------------------------+----------------------+------------------+

# %% [markdown]
# 2. All aircraft (registration, model) that have been assigned to more than 5 flights.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query_aircraft = """
SELECT
    aircraft_registration AS registration,
    aircraft_model AS model,
    COUNT(*) AS total_assignments
FROM (
    SELECT aircraft_registration, aircraft_model FROM new_departures_data WHERE aircraft_registration IS NOT NULL
    UNION ALL
    SELECT aircraft_registration, aircraft_model FROM new_arrivals_data WHERE aircraft_registration IS NOT NULL
)
GROUP BY registration, model
HAVING total_assignments > 5
ORDER BY total_assignments DESC;
"""

df_aircraft_assignments = pd.read_sql_query(query_aircraft, conn)

conn.close()

print("Aircraft with more than 5 assignments:")
print(tabulate(df_aircraft_assignments, headers='keys', tablefmt='fancy_grid'))
# Out:
# Aircraft with more than 5 assignments:
# ╒════╤════════════════╤═════════════════════════╤═════════════════════╕
# │    │ registration   │ model                   │   total_assignments │
# ╞════╪════════════════╪═════════════════════════╪═════════════════════╡
# │  0 │ F-HBLG         │ Embraer 190             │                  20 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  1 │ PH-EXJ         │ Embraer 175             │                  20 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  2 │ D-AIBC         │ Airbus A319             │                  19 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  3 │ D-ACNI         │ Canadair CRJ 900NG      │                  18 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  4 │ D-AIBD         │ Airbus A319             │                  18 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  5 │ D-AILN         │ Airbus A319             │                  16 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  6 │ D-AIBA         │ Airbus A319             │                  15 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  7 │ D-AIDG         │ Airbus A321             │                  14 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  8 │ D-AILA         │ Airbus A319             │                  14 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │  9 │ PH-EXP         │ Embraer 175             │                  14 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 10 │ D-AILL         │ Airbus A319             │                  13 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 11 │ D-AILY         │ Airbus A319             │                  13 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 12 │ D-AIWJ         │ Airbus A320             │                  13 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 13 │ D-AIWK         │ Airbus A320             │                  13 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 14 │ D-AIZE         │ Airbus A320             │                  13 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 15 │ D-ACNW         │ Canadair CRJ 900NG      │                  12 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 16 │ F-HZUX         │ Airbus A220-300         │                  12 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 17 │ D-AIWI         │ Airbus A320             │                  11 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 18 │ D-AIZF         │ Airbus A320             │                  11 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 19 │ D-AIZR         │ Airbus A320 (Sharklets) │                  11 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 20 │ 9V-SWV         │ Boeing 777-300          │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 21 │ C-GHKW         │ Airbus A330-300         │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 22 │ D-AIEQ         │ Airbus A321 NEO         │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 23 │ F-GKXL         │ Airbus A320             │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 24 │ PH-AXF         │ Airbus A321 NEO         │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 25 │ PH-AXK         │ Airbus A321 NEO         │                  10 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 26 │ 9V-SKP         │ Airbus A380-800         │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 27 │ D-AIBF         │ Airbus A319             │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 28 │ D-AIBJ         │ Airbus A319             │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 29 │ D-AILM         │ Airbus A319             │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 30 │ D-AINM         │ Airbus A321 (Sharklets) │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 31 │ D-AIUA         │ Airbus A320 (Sharklets) │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 32 │ D-AIZB         │ Airbus A320             │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 33 │ G-TTND         │ Airbus A320 (Sharklets) │                   9 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 34 │ C-GFAJ         │ Airbus A330-300         │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 35 │ CS-TVA         │ Airbus A320 (Sharklets) │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 36 │ D-AIEN         │ Airbus A321 NEO         │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 37 │ D-AIRP         │ Airbus A321             │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 38 │ D-AIRW         │ Airbus A321             │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 39 │ D-AISU         │ Airbus A321             │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 40 │ D-AIZM         │ Airbus A320             │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 41 │ I-ADJY         │ Embraer 195             │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 42 │ PH-AXA         │ Airbus A321 NEO         │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 43 │ PH-AXC         │ Airbus A321 NEO         │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 44 │ PH-BGG         │ Boeing 737              │                   8 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 45 │ A6-BLV         │ Boeing 787-9            │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 46 │ CS-TXD         │ Airbus A321             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 47 │ D-ABYJ         │ Boeing 747              │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 48 │ D-ABYP         │ Boeing 747-8            │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 49 │ D-AIBH         │ Airbus A319             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 50 │ D-AIEB         │ Airbus A321             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 51 │ D-AILC         │ Airbus A319             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 52 │ D-AILF         │ Airbus A319             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 53 │ D-AIRN         │ Airbus A321             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 54 │ D-AIZG         │ Airbus A320             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 55 │ EC-MJQ         │ Regional-Jet            │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 56 │ EC-NTQ         │ Airbus A320 NEO         │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 57 │ I-JENE         │ Embraer 190             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 58 │ PH-EXM         │ Embraer 175             │                   7 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 59 │ 9A-CAL         │ Airbus A220-300         │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 60 │ 9H-CXH         │ Boeing 737-800          │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 61 │ A6-BLJ         │ Boeing 787-9            │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 62 │ D-ABPF         │ Boeing 787-9            │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 63 │ D-ABPR         │ Boeing 787-9            │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 64 │ D-ACNF         │ Canadair CRJ 900        │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 65 │ D-AIBE         │ Airbus A319             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 66 │ D-AIDA         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 67 │ D-AIED         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 68 │ D-AIKO         │ Airbus A330             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 69 │ D-AILD         │ Airbus A319             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 70 │ D-AINJ         │ Airbus A321 (Sharklets) │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 71 │ D-AIQT         │ Airbus A320             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 72 │ D-AIRL         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 73 │ D-AIRU         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 74 │ D-AIRX         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 75 │ D-AISC         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 76 │ D-AIST         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 77 │ D-AISZ         │ Airbus A321             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 78 │ D-AIWA         │ Airbus A320             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 79 │ D-AIZJ         │ Airbus A320             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 80 │ D-AXGF         │ Airbus A330             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 81 │ EC-MEA         │ Airbus A320 (Sharklets) │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 82 │ EC-MEL         │ Airbus A320             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 83 │ I-ADJO         │ Embraer 195             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 84 │ I-JENH         │ Embraer 190             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 85 │ N502AE         │ Bombardier CRJ700       │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 86 │ OE-LBV         │ Airbus A320             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 87 │ PH-AXD         │ Airbus A321 NEO         │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 88 │ PH-BGA         │ Boeing 737              │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 89 │ PH-BXM         │ Boeing 737              │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 90 │ PH-EZX         │ Embraer 190             │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 91 │ PH-HSD         │ Boeing 737              │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 92 │ PT-MUG         │ Boeing 777-300          │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 93 │ VT-CIF         │ Airbus A321 (Sharklets) │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 94 │ VT-TQF         │ Airbus A320 NEO         │                   6 │
# ├────┼────────────────┼─────────────────────────┼─────────────────────┤
# │ 95 │ VT-YBA         │ Boeing 737 MAX 8        │                   6 │
# ╘════╧════════════════╧═════════════════════════╧═════════════════════╛

# %% [markdown]
# 3. Each airport, displaying its name and the number of outbound flights, with more than 5 flights.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    destination_airport_name AS airport_name,
    COUNT(*) AS outbound_flights_count
FROM new_departures_data
WHERE destination_airport_name IS NOT NULL AND destination_airport_name != 'Unknown'
GROUP BY airport_name
HAVING outbound_flights_count > 5
ORDER BY outbound_flights_count DESC;
"""

df_outbound_flights = pd.read_sql_query(query, conn)

conn.close()

print("Destination airports with more than 5 outbound flights:")
print(tabulate(df_outbound_flights, headers='keys', tablefmt='fancy_grid'))
# Out:
# Destination airports with more than 5 outbound flights:
# ╒═════╤════════════════════════════════════════════╤══════════════════════════╕
# │     │ airport_name                               │   outbound_flights_count │
# ╞═════╪════════════════════════════════════════════╪══════════════════════════╡
# │   0 │ New Delhi                                  │                       84 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   1 │ London                                     │                       79 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   2 │ Mumbai                                     │                       72 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   3 │ Shenzhen                                   │                       68 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   4 │ Guangzhou                                  │                       68 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   5 │ Bangalore                                  │                       54 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   6 │ Paris                                      │                       47 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   7 │ Beijing                                    │                       47 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   8 │ Singapore                                  │                       43 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │   9 │ Hyderabad                                  │                       42 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │  10 │ Chennai                                    │                       42 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │  11 │ Geneva                                     │                       41 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │
                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 100 │ Tel Aviv Yafo                              │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 101 │ Taipei                                     │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 102 │ Nuremberg                                  │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 103 │ Naqpur                                     │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 104 │ Lucknow                                    │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 105 │ Leipzig                                    │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 106 │ Guilin City                                │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 107 │ Firenze                                    │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 108 │ Colombo                                    │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 109 │ Casablanca                                 │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 110 │ Billund                                    │                       11 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 111 │ Nanchang                                   │                       10 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 112 │ Mopa                                       │                       10 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 113 │ Ho Chi Minh City                           │                       10 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 114 │ Guwahati                                   │                       10 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 115 │ Yantai                                     │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 116 │ Wenzhou                                    │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 117 │ Sharjah                                    │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 118 │ Shantou                                    │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 119 │ Shanghai                                   │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 120 │ Port Blair                                 │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 121 │ Osaka                                      │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 122 │ Nantes                                     │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 123 │ Indore                                     │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 124 │ Bordeaux/Mérignac                          │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 125 │ Anchorage                                  │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 126 │ Ad Dammam                                  │                        9 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 127 │ Visakhapatnam                              │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 128 │ Seattle                                    │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 129 │ Phuket                                     │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 130 │ Newark                                     │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 131 │ New York                                   │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 132 │ Luxembourg                                 │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 133 │ Hanoi                                      │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 134 │ Dresden                                    │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 135 │ Coimbatore                                 │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 136 │ Changsha                                   │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 137 │ Chandigarh                                 │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 138 │ Bucharest                                  │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 139 │ Belgrade                                   │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 140 │ Atlanta                                    │                        8 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 141 │ Varanasi                                   │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 142 │ Tunis                                      │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 143 │ Tallinn                                    │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 144 │ San Antonio                                │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 145 │ Newcastle upon Tyne                        │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 146 │ Nanjing                                    │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 147 │ Málaga                                     │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 148 │ Montpellier/Méditerranée                   │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 149 │ Miami                                      │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 150 │ Mexico City                                │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 151 │ Melbourne                                  │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 152 │ Marrakech                                  │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 153 │ Mangalore                                  │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 154 │ Kathmandu                                  │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 155 │ Hohhot                                     │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 156 │ Hefei                                      │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 157 │ Denver                                     │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 158 │ Chifeng                                    │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 159 │ Calicut                                    │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 160 │ Cairo                                      │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 161 │ Amritsar                                   │                        7 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 162 │ Zhengzhou                                  │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 163 │ Washington                                 │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 164 │ Torino                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 165 │ San Francisco                              │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 166 │ Rio de Janeiro                             │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 167 │ Raipur                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 168 │ Porto                                      │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 169 │ Phoenix                                    │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 170 │ Patna                                      │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 171 │ Oklahoma City                              │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 172 │ Nashville                                  │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 173 │ Moscow                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 174 │ Midland                                    │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 175 │ Manila                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 176 │ Malé                                       │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 177 │ Madurai                                    │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 178 │ Las Vegas                                  │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 179 │ Guiyang                                    │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 180 │ Fayetteville/Springdale/                   │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 181 │ Detroit                                    │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 182 │ Cape Town                                  │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 183 │ Bremen                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 184 │ Austin                                     │                        6 │
# ├─────┼────────────────────────────────────────────┼──────────────────────────┤
# │ 185 │ Almaty                                     │                        6 │
# ╘═════╧════════════════════════════════════════════╧══════════════════════════╛

# %% [markdown]
# 4. Top 3 destination airports (name, city) by number of arriving flights, sorted by descending.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    ad.full_name AS destination_airport_name,
    ad.municipality_name AS destination_airport_city,
    COUNT(*) AS total_arriving_flights
FROM new_arrivals_data na
LEFT JOIN airports_data ad ON na.arrival_airport_iata = ad.iata_code
WHERE ad.full_name IS NOT NULL
GROUP BY destination_airport_name, destination_airport_city
ORDER BY total_arriving_flights DESC
LIMIT 3;
"""

df_top_destination_airports = pd.read_sql_query(query, conn)

conn.close()

print("Top 3 destination airports with the highest number of arriving flights:")
print(tabulate(df_top_destination_airports, headers='keys', tablefmt='fancy_grid'))
# Out:
# Top 3 destination airports with the highest number of arriving flights:
# ╒════╤════════════════════════════╤════════════════════════════╤══════════════════════════╕
# │    │ destination_airport_name   │ destination_airport_city   │   total_arriving_flights │
# ╞════╪════════════════════════════╪════════════════════════════╪══════════════════════════╡
# │  0 │ Shanghai Pudong            │ Shanghai                   │                      906 │
# ├────┼────────────────────────────┼────────────────────────────┼──────────────────────────┤
# │  1 │ Paris Charles de Gaulle    │ Paris                      │                      464 │
# ├────┼────────────────────────────┼────────────────────────────┼──────────────────────────┤
# │  2 │ Frankfurt-am-Main          │ Frankfurt-am-Main          │                      435 │
# ╘════╧════════════════════════════╧════════════════════════════╧══════════════════════════╛

# %% [markdown]
# 5. For each flight: number, origin, destination, and a label 'Domestic' or 'International'

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    nd.flight_number AS flight_number,
    ad_orig.full_name AS origin_airport,
    ad_dest.full_name AS destination_airport,
    CASE
        WHEN ad_orig.country_name = ad_dest.country_name THEN 'Domestic'
        ELSE 'International'
    END AS flight_type
FROM
    new_departures_data nd
LEFT JOIN
    airports_data ad_orig ON nd.origin_airport_iata = ad_orig.iata_code
LEFT JOIN
    airports_data ad_dest ON nd.destination_airport_iata = ad_dest.iata_code
WHERE
    ad_orig.full_name IS NOT NULL AND ad_dest.full_name IS NOT NULL
ORDER BY
    flight_number ASC;
"""

df_flight_types = pd.read_sql_query(query, conn)

conn.close()

print("Flight types (Domestic/International) for the first 100 flights:")
print(tabulate(df_flight_types, headers='keys', tablefmt='fancy_grid'))
# Out:
# Flight types (Domestic/International) for the first 100 flights:
# ╒═════╤═════════════════╤══════════════════════════════╤══════════════════════════════╤═══════════════╕
# │     │ flight_number   │ origin_airport               │ destination_airport          │ flight_type   │
# ╞═════╪═════════════════╪══════════════════════════════╪══════════════════════════════╪═══════════════╡
# │   0 │ 5J 15           │ Dubai                        │ Dallas-Fort Worth            │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   1 │ 6E 102          │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   2 │ 6E 136          │ Mumbai Chhatrapati Shivaji   │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   3 │ 6E 1456         │ Dubai                        │ Mumbai Chhatrapati Shivaji   │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   4 │ 6E 1461         │ New Delhi Indira Gandhi      │ Dubai                        │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   5 │ 6E 1471         │ Chennai                      │ Dubai                        │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   6 │ 6E 1472         │ Dubai                        │ Chennai                      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   7 │ 6E 1486         │ Dubai                        │ Bangalore Bengaluru          │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   8 │ 6E 1607         │ Mumbai Chhatrapati Shivaji   │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │   9 │ 6E 1608         │ Chennai                      │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  10 │ 6E 189          │ Chennai                      │ Bangalore Bengaluru          │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  11 │ 6E 195          │ Hyderabad Rajiv Gandhi       │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  12 │ 6E 2007         │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  13 │ 6E 2027         │ New Delhi Indira Gandhi      │ Hyderabad Rajiv Gandhi       │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  14 │ 6E 2053         │ Indore Devi Ahilyabai Holkar │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  15 │ 6E 2062         │ Bangalore Bengaluru          │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  16 │ 6E 21           │ Mumbai Chhatrapati Shivaji   │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  17 │ 6E 2156         │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  18 │ 6E 2228         │ Chennai                      │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  19 │ 6E 2233         │ Hyderabad Rajiv Gandhi       │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  20 │ 6E 225          │ Mumbai Chhatrapati Shivaji   │ Indore Devi Ahilyabai Holkar │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  21 │ 6E 2253         │ New Delhi Indira Gandhi      │ Hyderabad Rajiv Gandhi       │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  22 │ 6E 2255         │ New Delhi Indira Gandhi      │ Hyderabad Rajiv Gandhi       │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  23 │ 6E 2256         │ Hyderabad Rajiv Gandhi       │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │  24 │ 6E 2386         │ New Delhi Indira Gandhi      │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │
 New Delhi Indira Gandhi      │ Bangalore Bengaluru          │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 448 │ SG 169          │ New Delhi Indira Gandhi      │ Shanghai Pudong              │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 449 │ SG 268          │ Bangalore Bengaluru          │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 450 │ SG 2987         │ Chennai                      │ Hyderabad Rajiv Gandhi       │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 451 │ SG 2988         │ Hyderabad Rajiv Gandhi       │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 452 │ SG 385          │ New Delhi Indira Gandhi      │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 453 │ SG 386          │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 454 │ SG 555          │ Mumbai Chhatrapati Shivaji   │ Bangalore Bengaluru          │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 455 │ SG 59           │ Mumbai Chhatrapati Shivaji   │ Dubai                        │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 456 │ SG 648          │ Mumbai Chhatrapati Shivaji   │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 457 │ SG 655          │ Bangalore Bengaluru          │ Mumbai Chhatrapati Shivaji   │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 458 │ SG 660          │ Chennai                      │ Hyderabad Rajiv Gandhi       │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 459 │ SG 661          │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 460 │ SG 672          │ Chennai                      │ Bangalore Bengaluru          │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 461 │ SG 678          │ Mumbai Chhatrapati Shivaji   │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 462 │ SG 940          │ Mumbai Chhatrapati Shivaji   │ Chennai                      │ Domestic      │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 463 │ SK 6648         │ Amsterdam Schiphol           │ Frankfurt-am-Main            │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 464 │ SK 6651         │ Frankfurt-am-Main            │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 465 │ SK 9751         │ Paris Charles de Gaulle      │ Frankfurt-am-Main            │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 466 │ SK 9833         │ Frankfurt-am-Main            │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 467 │ SK 9986         │ Paris Charles de Gaulle      │ Dubai                        │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 468 │ TG 7604         │ Frankfurt-am-Main            │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 469 │ TG 7652         │ Frankfurt-am-Main            │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 470 │ TP 7044         │ Frankfurt-am-Main            │ New Delhi Indira Gandhi      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 471 │ UA 9147         │ Frankfurt-am-Main            │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 472 │ UA 9156         │ Amsterdam Schiphol           │ Frankfurt-am-Main            │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 473 │ UA 9353         │ Frankfurt-am-Main            │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 474 │ UU 8240         │ Paris Charles de Gaulle      │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 475 │ VN 3107         │ Amsterdam Schiphol           │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 476 │ VN 3131         │ Frankfurt-am-Main            │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 477 │ VN 3173         │ Amsterdam Schiphol           │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 478 │ WS 5058         │ Frankfurt-am-Main            │ Paris Charles de Gaulle      │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 479 │ WS 5067         │ Paris Charles de Gaulle      │ Frankfurt-am-Main            │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 480 │ WY 5376         │ Frankfurt-am-Main            │ Amsterdam Schiphol           │ International │
# ├─────┼─────────────────┼──────────────────────────────┼──────────────────────────────┼───────────────┤
# │ 481 │ Y8 7441         │ Shanghai Pudong              │ Mumbai Chhatrapati Shivaji   │ International │
# ╘═════╧═════════════════╧══════════════════════════════╧══════════════════════════════╧═══════════════╛

# %% [markdown]
# 6. 5 most recent arrivals at “DEL” airport including flight number, aircraft, departure airport name, and arrival time, ordered by latest arrival.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    flight_number,
    aircraft_model,
    origin_airport_name AS departure_airport_name,
    scheduled_arrival_time_utc AS scheduled_arrival_time
FROM
    new_arrivals_data
WHERE
    arrival_airport_iata = 'DEL'
ORDER BY
    scheduled_arrival_time DESC
LIMIT 5;
"""

df_del_arrivals = pd.read_sql_query(query, conn)

conn.close()

print("5 most recent arrivals at DEL airport:")
print(tabulate(df_del_arrivals, headers='keys', tablefmt='fancy_grid'))
# Out:
# 5 most recent arrivals at DEL airport:
# ╒════╤═════════════════╤══════════════════╤══════════════════════════╤══════════════════════════╕
# │    │ flight_number   │ aircraft_model   │ departure_airport_name   │ scheduled_arrival_time   │
# ╞════╪═════════════════╪══════════════════╪══════════════════════════╪══════════════════════════╡
# │  0 │ QP 1359         │ Boeing 737       │ Bangalore                │ 2025-11-30 02:25Z        │
# ├────┼─────────────────┼──────────────────┼──────────────────────────┼──────────────────────────┤
# │  1 │ 6E 1232         │ Airbus A320 NEO  │ Kuwait City              │ 2025-11-30 02:20Z        │
# ├────┼─────────────────┼──────────────────┼──────────────────────────┼──────────────────────────┤
# │  2 │ AI 1806         │ Airbus A320 NEO  │ Hyderabad                │ 2025-11-30 02:15Z        │
# ├────┼─────────────────┼──────────────────┼──────────────────────────┼──────────────────────────┤
# │  3 │ AI 2404         │ Airbus A320 NEO  │ Pune                     │ 2025-11-30 02:15Z        │
# ├────┼─────────────────┼──────────────────┼──────────────────────────┼──────────────────────────┤
# │  4 │ SG 8194         │ Boeing 737-800   │ Ahmedabad                │ 2025-11-30 02:10Z        │
# ╘════╧═════════════════╧══════════════════╧══════════════════════════╧══════════════════════════╛

# %% [markdown]
# 7. All airports with no arriving flights.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    ad.full_name AS airport_name,
    ad.iata_code AS airport_iata
FROM
    airports_data ad
LEFT JOIN
    new_arrivals_data na ON ad.iata_code = na.arrival_airport_iata
WHERE
    na.arrival_airport_iata IS NULL;
"""

df_no_arrivals = pd.read_sql_query(query, conn)

conn.close()

print("Airports with no recorded arrivals:")
print(tabulate(df_no_arrivals, headers='keys', tablefmt='fancy_grid'))
# Out:
# Airports with no recorded arrivals:
# ╒════════════════╤════════════════╕
# │ airport_name   │ airport_iata   │
# ╞════════════════╪════════════════╡
# ╘════════════════╧════════════════╛

# %% [markdown]
# 8. For each airline, count the number of flights by status using CASE WHEN.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    airline_name,
    COUNT(CASE WHEN flight_status = 'Departed' THEN 1 ELSE NULL END) AS departed_flights,
    COUNT(CASE WHEN flight_status = 'Expected' THEN 1 ELSE NULL END) AS expected_flights,
    COUNT(CASE WHEN flight_status NOT IN ('Departed', 'Expected') THEN 1 ELSE NULL END) AS other_status_flights,
    COUNT(*) AS total_flights
FROM
    new_departures_data
WHERE
    airline_name IS NOT NULL
GROUP BY
    airline_name
ORDER BY
    total_flights DESC;
"""

df_flight_status_counts = pd.read_sql_query(query, conn)

conn.close()

print("Flight status counts for each airline:")
print(tabulate(df_flight_status_counts, headers='keys', tablefmt='fancy_grid'))
# Out:
# Flight status counts for each airline:
# ╒═════╤══════════════════════════════╤════════════════════╤════════════════════╤════════════════════════╤═════════════════╕
# │     │ airline_name                 │   departed_flights │   expected_flights │   other_status_flights │   total_flights │
# ╞═════╪══════════════════════════════╪════════════════════╪════════════════════╪════════════════════════╪═════════════════╡
# │   0 │ IndiGo                       │                129 │                  5 │                    291 │             425 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   1 │ American                     │                224 │                  4 │                     64 │             292 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   2 │ Air India                    │                 78 │                  0 │                    134 │             212 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   3 │ China Eastern                │                198 │                  0 │                     12 │             210 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   4 │ KLM                          │                133 │                  0 │                      4 │             137 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   5 │ Lufthansa                    │                129 │                  0 │                      2 │             131 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   6 │ Emirates                     │                 60 │                  0 │                     69 │             129 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   7 │ Air France                   │                126 │                  0 │                      3 │             129 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   8 │ Xiamen                       │                113 │                  0 │                      8 │             121 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │   9 │ Juneyao                      │                101 │                  0 │                      6 │             107 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  10 │ flydubai                     │                 30 │                  1 │                     52 │              83 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  11 │ Air India Express            │                 34 │                  0 │                     43 │              77 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  12 │ ANA                          │                 77 │                  0 │                      0 │              77 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  13 │ Delta Air Lines              │                 70 │                  0 │                      4 │              74 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  14 │ Air China                    │                 64 │                  0 │                      4 │              68 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  15 │ China Southern               │                 61 │                  0 │                      4 │              65 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  16 │ Etihad                       │                 50 │                  0 │                     13 │              63 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │  17 │ Sichuan                      │                 57 │                  0 │                      3 │              60 │
# ├─────┼──────────────────────────────┼────────────────────┼────────────────────┼────────────────────────┼─────────────────┤
# │


# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    nd.flight_number,
    nd.aircraft_model,
    ad_origin.full_name AS origin_airport,
    ad_destination.full_name AS destination_airport,
    nd.scheduled_departure_time_utc
FROM
    new_departures_data nd
LEFT JOIN
    airports_data ad_origin ON nd.origin_airport_iata = ad_origin.iata_code
LEFT JOIN
    airports_data ad_destination ON nd.destination_airport_iata = ad_destination.iata_code
WHERE
    nd.flight_status = 'Delayed'
ORDER BY
    nd.scheduled_departure_time_utc DESC;
"""

df_delayed_flights = pd.read_sql_query(query, conn)

conn.close()

print("Details of delayed flights:")
print(tabulate(df_delayed_flights, headers='keys', tablefmt='fancy_grid'))
# Out:
# Details of delayed flights:
# ╒════╤═════════════════╤══════════════════╤═════════════════════╤════════════════════════╤════════════════════════════════╕
# │    │ flight_number   │ aircraft_model   │ origin_airport      │ destination_airport    │ scheduled_departure_time_utc   │
# ╞════╪═════════════════╪══════════════════╪═════════════════════╪════════════════════════╪════════════════════════════════╡
# │  0 │ 6E 6178         │ Airbus A321 NEO  │ Bangalore Bengaluru │ Hyderabad Rajiv Gandhi │ 2025-11-29 17:45Z              │
# ╘════╧═════════════════╧══════════════════╧═════════════════════╧════════════════════════╧════════════════════════════════╛

# %% [markdown]
# 10. City pairs that have more than 2 different aircraft models operating flights between them.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    ad_orig.full_name AS origin_airport,
    ad_dest.full_name AS destination_airport,
    COUNT(DISTINCT nd.aircraft_model) AS distinct_aircraft_models
FROM
    new_departures_data nd
JOIN
    airports_data ad_orig ON nd.origin_airport_iata = ad_orig.iata_code
JOIN
    airports_data ad_dest ON nd.destination_airport_iata = ad_dest.iata_code
WHERE
    nd.aircraft_model IS NOT NULL
GROUP BY
    origin_airport,
    destination_airport
HAVING
    COUNT(DISTINCT nd.aircraft_model) > 2
ORDER BY
    distinct_aircraft_models DESC;
"""

df_city_pairs_aircraft_models = pd.read_sql_query(query, conn)

conn.close()

print("City pairs with more than 2 distinct aircraft models:")
print(tabulate(df_city_pairs_aircraft_models, headers='keys', tablefmt='fancy_grid'))
# Out:
# City pairs with more than 2 distinct aircraft models:
# ╒════╤══════════════════════════════╤══════════════════════════════╤════════════════════════════╕
# │    │ origin_airport               │ destination_airport          │   distinct_aircraft_models │
# ╞════╪══════════════════════════════╪══════════════════════════════╪════════════════════════════╡
# │  0 │ New Delhi Indira Gandhi      │ Mumbai Chhatrapati Shivaji   │                          8 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  1 │ Bangalore Bengaluru          │ Mumbai Chhatrapati Shivaji   │                          7 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  2 │ Bangalore Bengaluru          │ New Delhi Indira Gandhi      │                          7 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  3 │ Mumbai Chhatrapati Shivaji   │ New Delhi Indira Gandhi      │                          7 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  4 │ Bangalore Bengaluru          │ Chennai                      │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  5 │ Bangalore Bengaluru          │ Hyderabad Rajiv Gandhi       │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  6 │ Dubai                        │ New Delhi Indira Gandhi      │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  7 │ Hyderabad Rajiv Gandhi       │ Bangalore Bengaluru          │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  8 │ Mumbai Chhatrapati Shivaji   │ Bangalore Bengaluru          │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │  9 │ New Delhi Indira Gandhi      │ Bangalore Bengaluru          │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 10 │ New Delhi Indira Gandhi      │ Dubai                        │                          6 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 11 │ Dubai                        │ Hyderabad Rajiv Gandhi       │                          5 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 12 │ Dubai                        │ Mumbai Chhatrapati Shivaji   │                          5 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 13 │ Mumbai Chhatrapati Shivaji   │ Chennai                      │                          5 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 14 │ Mumbai Chhatrapati Shivaji   │ Dubai                        │                          5 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 15 │ Frankfurt-am-Main            │ Amsterdam Schiphol           │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 16 │ Hyderabad Rajiv Gandhi       │ Mumbai Chhatrapati Shivaji   │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 17 │ Indore Devi Ahilyabai Holkar │ New Delhi Indira Gandhi      │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 18 │ New Delhi Indira Gandhi      │ Hyderabad Rajiv Gandhi       │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 19 │ New Delhi Indira Gandhi      │ Indore Devi Ahilyabai Holkar │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 20 │ Paris Charles de Gaulle      │ Frankfurt-am-Main            │                          4 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 21 │ Amsterdam Schiphol           │ Paris Charles de Gaulle      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 22 │ Chennai                      │ Bangalore Bengaluru          │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 23 │ Chennai                      │ Dubai                        │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 24 │ Chennai                      │ Hyderabad Rajiv Gandhi       │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 25 │ Chennai                      │ Mumbai Chhatrapati Shivaji   │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 26 │ Chennai                      │ New Delhi Indira Gandhi      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 27 │ Dubai                        │ Bangalore Bengaluru          │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 28 │ Dubai                        │ Chennai                      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 29 │ Dubai                        │ Frankfurt-am-Main            │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 30 │ Dubai                        │ Paris Charles de Gaulle      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 31 │ Frankfurt-am-Main            │ Paris Charles de Gaulle      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 32 │ Hyderabad Rajiv Gandhi       │ Chennai                      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 33 │ Hyderabad Rajiv Gandhi       │ New Delhi Indira Gandhi      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 34 │ Mumbai Chhatrapati Shivaji   │ Hyderabad Rajiv Gandhi       │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 35 │ New Delhi Indira Gandhi      │ Chennai                      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 36 │ New Delhi Indira Gandhi      │ Paris Charles de Gaulle      │                          3 │
# ├────┼──────────────────────────────┼──────────────────────────────┼────────────────────────────┤
# │ 37 │ Shanghai Pudong              │ Frankfurt-am-Main            │                          3 │
# ╘════╧══════════════════════════════╧══════════════════════════════╧════════════════════════════╛

# %% [markdown]
# 11. The % of delayed flights (status='Delayed') among all arrivals, sorted by highest percentage.

# %%
import sqlite3
import pandas as pd

db_name = 'flight_data.db'
conn = sqlite3.connect(db_name)

query = """
SELECT
    ad.full_name AS destination_airport_name,
    SUM(CASE WHEN na.flight_status = 'Delayed' THEN 1 ELSE 0 END) AS delayed_arrivals_count,
    COUNT(na.flight_number) AS total_arrivals_count,
    CAST(SUM(CASE WHEN na.flight_status = 'Delayed' THEN 1 ELSE 0 END) AS REAL) * 100 / COUNT(na.flight_number) AS percentage_delayed
FROM
    new_arrivals_data na
JOIN
    airports_data ad ON na.arrival_airport_iata = ad.iata_code -- Corrected column name to 'arrival_airport_iata'
GROUP BY
    ad.full_name
HAVING
    total_arrivals_count > 0
ORDER BY
    percentage_delayed DESC;
"""

df_delayed_percentage = pd.read_sql_query(query, conn)

conn.close()

print("Percentage of delayed flights for each destination airport:")
print(tabulate(df_delayed_percentage, headers='keys', tablefmt='fancy_grid'))
# Out:
# Percentage of delayed flights for each destination airport:
# ╒════╤══════════════════════════════╤══════════════════════════╤════════════════════════╤══════════════════════╕
# │    │ destination_airport_name     │   delayed_arrivals_count │   total_arrivals_count │   percentage_delayed │
# ╞════╪══════════════════════════════╪══════════════════════════╪════════════════════════╪══════════════════════╡
# │  0 │ Bangalore Bengaluru          │                       10 │                    179 │             5.58659  │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  1 │ Paris Charles de Gaulle      │                        3 │                    464 │             0.646552 │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  2 │ Shanghai Pudong              │                        0 │                    906 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  3 │ New Delhi Indira Gandhi      │                        0 │                    269 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  4 │ Mumbai Chhatrapati Shivaji   │                        0 │                    214 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  5 │ Indore Devi Ahilyabai Holkar │                        0 │                     19 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  6 │ Hyderabad Rajiv Gandhi       │                        0 │                    121 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  7 │ Frankfurt-am-Main            │                        0 │                    435 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  8 │ Dubai                        │                        0 │                    363 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │  9 │ Dallas-Fort Worth            │                        0 │                    430 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │ 10 │ Chennai                      │                        0 │                     99 │             0        │
# ├────┼──────────────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────┤
# │ 11 │ Amsterdam Schiphol           │                        0 │                    182 │             0        │
# ╘════╧══════════════════════════════╧══════════════════════════╧════════════════════════╧══════════════════════╛

# %% [markdown]
# Stramlit Application

# %%
pip install matplotlib seaborn plotly
# Out:
# Requirement already satisfied: matplotlib in c:\users\karth\downloads\code\env\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\karth\downloads\code\env\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\karth\downloads\code\env\lib\site-packages (6.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karth\downloads\code\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\karth\downloads\code\env\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\karth\downloads\code\env\lib\site-packages (from plotly) (2.14.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karth\downloads\code\env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karth\downloads\code\env\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\karth\downloads\code\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile streamlit.py
import streamlit as st
import pandas as pd
from tabulate import tabulate
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

#to connect to the database
def get_data(query):
    conn = sqlite3.connect('flight_data.db')
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

# Title
st.title("Flight Data Analysis Dashboard")  

# sidebar for navigation
st.sidebar.title("Navigation")
page = st.sidebar.selectbox("Select a page:", ["Home", "Arrival and Departure Data","Arrival & Departure Visualizations","Query Execution","Creator Info"])

#---------------- Home Page ----------------
if page == "Home":
    st.title("Flight Data Analytics Home")
    st.image("C:/Users/karth/Downloads/airplane-taking-off-stockcake-1.jpg")
    st.write("""
    Welcome to the Flight Data Analytics Dashboard! This application provides insights into flight operations, including arrivals and departures.
    Navigate through the sidebar to explore different sections of the dashboard.

    **Features:**
    - Detailed arrival and departure data Airport city-wise.
    - Interactive visualizations of Arrival and Departure data based on Airport city.
    - Execute predefined SQL queries on the flight database to view the results.
    - Information about the creator of this dashboard.
    """)

#---------------- Query Execution Page ----------------
elif page == "Query Execution":
    st.title("Pre defined SQL Query Execution")
    st.write("Execute predefined SQL queries on the flight database and view the results.")

    queries = {
    "1. Total number of flights for each aircraft model": """
    SELECT
        aircraft_model,
        COUNT(*) AS total_flights
    FROM (
        SELECT aircraft_model FROM new_departures_data
        UNION ALL
        SELECT aircraft_model FROM new_arrivals_data
    )
    WHERE aircraft_model IS NOT NULL
    GROUP BY aircraft_model
    ORDER BY total_flights DESC;
    """,
    "2. all aircraft (registration, model) that have been assigned to more than 5 flights": """
    SELECT
        aircraft_registration AS registration,
        aircraft_model AS model,
        COUNT(*) AS total_assignments
    FROM (
        SELECT aircraft_registration, aircraft_model FROM new_departures_data WHERE aircraft_registration IS NOT NULL
        UNION ALL
        SELECT aircraft_registration, aircraft_model FROM new_arrivals_data WHERE aircraft_registration IS NOT NULL
    )
    GROUP BY registration, model
    HAVING total_assignments > 5
    ORDER BY total_assignments DESC;
    """,
    "3. In each airport, display its name and the number of outbound flights, but only for airports with more than 5 flights.": """
    SELECT
        destination_airport_name AS airport_name,
        COUNT(*) AS outbound_flights_count
    FROM new_departures_data
    WHERE destination_airport_name IS NOT NULL AND destination_airport_name != 'Unknown'
    GROUP BY airport_name
    HAVING outbound_flights_count > 5
    ORDER BY outbound_flights_count DESC;
    """,
    "4. Top 3 destination airports (name, city) by number of arriving flights, sorted by count descending.": """
    SELECT
        ad.full_name AS destination_airport_name,
        ad.municipality_name AS destination_airport_city,
        COUNT(*) AS total_arriving_flights
    FROM new_arrivals_data na
    LEFT JOIN airports_data ad ON na.arrival_airport_iata = ad.iata_code
    WHERE ad.full_name IS NOT NULL
    GROUP BY destination_airport_name, destination_airport_city
    ORDER BY total_arriving_flights DESC
    LIMIT 3;
    """,
    "5. For each flight: number, origin, destination, and a label 'Domestic' or 'International' using CASE WHEN on country match.": """
    SELECT
        nd.flight_number AS flight_number,
        ad_orig.full_name AS origin_airport,
        ad_dest.full_name AS destination_airport,
        CASE
            WHEN ad_orig.country_name = ad_dest.country_name THEN 'Domestic'
            ELSE 'International'
        END AS flight_type
    FROM
        new_departures_data nd
    LEFT JOIN
        airports_data ad_orig ON nd.origin_airport_iata = ad_orig.iata_code
    LEFT JOIN
        airports_data ad_dest ON nd.destination_airport_iata = ad_dest.iata_code
    WHERE
        ad_orig.full_name IS NOT NULL AND ad_dest.full_name IS NOT NULL
    ORDER BY
        flight_number ASC;
    """,
    "6. 5 most recent arrivals at “DEL” airport.": """
    SELECT
        flight_number,
        aircraft_model,
        origin_airport_name AS departure_airport_name,
        scheduled_arrival_time_utc AS scheduled_arrival_time
    FROM
        new_arrivals_data
    WHERE
        arrival_airport_iata = 'DEL'
    ORDER BY
        scheduled_arrival_time DESC
    LIMIT 5;
    """,
    "7. Airports with no arriving flights": """
    SELECT
        ad.full_name AS airport_name,
        ad.iata_code AS airport_iata
    FROM
        airports_data ad
    LEFT JOIN
        new_arrivals_data na ON ad.iata_code = na.arrival_airport_iata
    WHERE
        na.arrival_airport_iata IS NULL;
    """,
    "8.For each airline, count the number of flights by status using CASE WHEN.": """
    SELECT
        airline_name,
        COUNT(CASE WHEN flight_status = 'Departed' THEN 1 ELSE NULL END) AS departed_flights,
        COUNT(CASE WHEN flight_status = 'Expected' THEN 1 ELSE NULL END) AS expected_flights,
        COUNT(CASE WHEN flight_status NOT IN ('Departed', 'Expected') THEN 1 ELSE NULL END) AS other_status_flights,
        COUNT(*) AS total_flights
    FROM
        new_departures_data
    WHERE
        airline_name IS NOT NULL
    GROUP BY
        airline_name
    ORDER BY
        total_flights DESC;
    """,
    "9.All delayed flights with details": """
    SELECT
        nd.flight_number,
        nd.aircraft_model,
        ad_origin.full_name AS origin_airport,
        ad_destination.full_name AS destination_airport,
        nd.scheduled_departure_time_utc
    FROM
        new_departures_data nd
    LEFT JOIN
        airports_data ad_origin ON nd.origin_airport_iata = ad_origin.iata_code
    LEFT JOIN
        airports_data ad_destination ON nd.destination_airport_iata = ad_destination.iata_code
    WHERE
        nd.flight_status = 'Delayed'
    ORDER BY
        nd.scheduled_departure_time_utc DESC;
    """,
    "10.All city pairs that have more than 2 different aircraft models.": """
    SELECT
        ad_orig.full_name AS origin_airport,
        ad_dest.full_name AS destination_airport,
        COUNT(DISTINCT nd.aircraft_model) AS distinct_aircraft_models
    FROM
        new_departures_data nd
    JOIN
        airports_data ad_orig ON nd.origin_airport_iata = ad_orig.iata_code
    JOIN
        airports_data ad_dest ON nd.destination_airport_iata = ad_dest.iata_code
    WHERE
        nd.aircraft_model IS NOT NULL
    GROUP BY
        origin_airport,
        destination_airport
    HAVING
        COUNT(DISTINCT nd.aircraft_model) > 2
    ORDER BY
        distinct_aircraft_models DESC;
    """,
    "11. percentage of delayed flights for each destination airport": """
    SELECT
        ad.full_name AS destination_airport_name,
        SUM(CASE WHEN na.flight_status = 'Delayed' THEN 1 ELSE 0 END) AS delayed_arrivals_count,
        COUNT(na.flight_number) AS total_arrivals_count,
        CAST(SUM(CASE WHEN na.flight_status = 'Delayed' THEN 1 ELSE 0 END) AS REAL) * 100 / COUNT(na.flight_number) AS percentage_delayed
    FROM
        new_arrivals_data na
    JOIN
        airports_data ad ON na.arrival_airport_iata = ad.iata_code -- Corrected column name to 'arrival_airport_iata'
    GROUP BY
        ad.full_name
    HAVING
        total_arrivals_count > 0
    ORDER BY
        percentage_delayed DESC;
    """
    }
    selected_query = st.selectbox("Select a SQL query to execute:", list(queries.keys()))
    if selected_query:
        query = queries[selected_query]
        df_result = get_data(query)
        st.write("Query Result:")
        st.dataframe(df_result)

#---------------- Arrival and Departure Data with respect to Airport city ----------------
elif page == "Arrival and Departure Data":
    st.title("Arrival and Departure Data with respect to Airport city")
    st.write("View arrival and departure data for a specific airport city.")

    airport_city = st.selectbox("Select an Airport City:", {municipality for municipality in pd.read_sql_query("SELECT DISTINCT municipality_name FROM airports_data WHERE municipality_name IS NOT NULL;", sqlite3.connect('flight_data.db'))['municipality_name']})


    if airport_city:        
        query_arrivals = f"""
        SELECT
            na.flight_number,
            na.aircraft_model,
            ad_origin.full_name AS origin_airport,
            ad_dest.full_name AS destination_airport,
            na.scheduled_arrival_time_utc AS scheduled_arrival_time,
            na.flight_status
        FROM
            new_arrivals_data na
        LEFT JOIN
            airports_data ad_origin ON na.origin_airport_iata = ad_origin.iata_code
        LEFT JOIN
            airports_data ad_dest ON na.arrival_airport_iata = ad_dest.iata_code
        WHERE
            ad_dest.municipality_name = '{airport_city}' AND ad_origin.full_name IS NOT NULL
        ORDER BY
            na.scheduled_arrival_time_utc DESC;
        """
        query_departures = f"""
        SELECT
            nd.flight_number,
            nd.aircraft_model,
            ad_origin.full_name AS origin_airport,
            ad_dest.full_name AS destination_airport,
            nd.scheduled_departure_time_utc AS scheduled_departure_time,
            nd.flight_status
        FROM
            new_departures_data nd
        LEFT JOIN
            airports_data ad_origin ON nd.origin_airport_iata = ad_origin.iata_code
        LEFT JOIN
            airports_data ad_dest ON nd.destination_airport_iata = ad_dest.iata_code
        WHERE
            ad_dest.municipality_name = '{airport_city}'
        ORDER BY
            nd.scheduled_departure_time_utc DESC;
        """

        df_departures = get_data(query_departures)
        df_arrivals = get_data(query_arrivals)
        st.subheader(f"Departures to {airport_city}")
        st.dataframe(df_departures)
        st.subheader(f"Arrivals to {airport_city}")
        st.dataframe(df_arrivals)


#---------------- Arrival & Departure Visualizations Page ----------------
elif page == "Arrival & Departure Visualizations":
    st.title("Arrival & Departure Visualizations")
    st.write("Visualize flight data with interactive charts.")

    departure_city_viz = st.selectbox("Select a Departure City for Visualization:", {municipality for municipality in pd.read_sql_query("SELECT DISTINCT municipality_name FROM airports_data WHERE municipality_name IS NOT NULL;", sqlite3.connect('flight_data.db'))['municipality_name']})

    if departure_city_viz:
        query_viz = f"""
        SELECT
            nd.flight_status,
            COUNT(*) AS count
        FROM
            new_departures_data nd
        LEFT JOIN
            airports_data ad_orig ON nd.origin_airport_iata = ad_orig.iata_code
        WHERE
            ad_orig.municipality_name = '{departure_city_viz}'
        GROUP BY
            nd.flight_status;
        """
        df_viz = get_data(query_viz)

    # Bar chart
        st.subheader(f"Flight Status Distribution for {departure_city_viz}")
        fig, ax = plt.subplots()
        sns.barplot(data=df_viz, x='flight_status', y='count', ax=ax)
        ax.set_xlabel("Flight Status")
        ax.set_ylabel("Count")
        ax.set_title(f"Flight Status Distribution for {departure_city_viz}")
        st.pyplot(fig)

    airport_city_viz = st.selectbox("Select an Arrival City for Visualization:", {municipality for municipality in pd.read_sql_query("SELECT DISTINCT municipality_name FROM airports_data WHERE municipality_name IS NOT NULL;", sqlite3.connect('flight_data.db'))['municipality_name']})

    if airport_city_viz:
        query_viz = f"""
        SELECT
            na.flight_status,
            COUNT(*) AS count
        FROM
            new_arrivals_data na
        LEFT JOIN
            airports_data ad_dest ON na.arrival_airport_iata = ad_dest.iata_code
        WHERE
            ad_dest.municipality_name = '{airport_city_viz}'
        GROUP BY
            na.flight_status;
        """
        df_viz = get_data(query_viz)

    # Bar chart
        st.subheader(f"Flight Status Distribution for {airport_city_viz}")
        fig, ax = plt.subplots()
        sns.barplot(data=df_viz, x='flight_status', y='count', ax=ax)
        ax.set_xlabel("Flight Status")
        ax.set_ylabel("Count")
        ax.set_title(f"Flight Status Distribution for {airport_city_viz}")
        st.pyplot(fig)


#---------------- Creator Info Page ----------------
elif page == "Creator Info":
    st.title("Creator Information")
    st.image("C:/Users/karth/Downloads/Profile-Pic.jpeg", width=200)
    st.write("""
    **Name:** Karthik G 
    **Email:** karthikg2112@gmail.com
    **GitHub:** [karthikg2112](https://github.com/karthikg2112)
    **LinkedIn:** [Karthik G](https://www.linkedin.com/in/karthik-g-620760369?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app)
    """
    )
# Out:
# Overwriting streamlit.py

# %%
# !streamlit run streamlit.py
